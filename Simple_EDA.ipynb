# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the student enrolments data from the excel file 
Student_df = pd.read_excel("01-student-enrolments.xlsx", header=None, names = ["University","2009 – Headcounts","2009 - FTEs","2010 – Headcounts","2010 – FTEs","2011 – Headcounts",
                                                                                "2011 – FTEs","2012 – Headcounts","2012 – FTEs","2013 – Headcounts","2013 – FTEs"])
#Check the first 5 rows of the data
Student_df.head()
# Out:
#                                         University  2009 – Headcounts  \
# 0  Table 1 - Total Enrolments and FTEs 2009 - 2013                NaN
# 1                                              NaN                NaN
# 2                                       University  2009 – Headcounts
# 3                                             CPUT              30958
# 4                                              UCT              23787
#
#    2009 - FTEs  2010 – Headcounts  2010 – FTEs  2011 – Headcounts  \
# 0          NaN                NaN          NaN                NaN
# 1          NaN                NaN          NaN                NaN
# 2  2009 - FTEs  2010 – Headcounts  2010 – FTEs  2011 – Headcounts
# 3        22690              32167        23854              32506
# 4        18854              24772        19652              25301
#
#    2011 – FTEs  2012 – Headcounts  2012 – FTEs  2013 – Headcounts  2013 – FTEs
# 0          NaN                NaN          NaN                NaN          NaN
# 1          NaN                NaN          NaN                NaN          NaN
# 2  2011 – FTEs  2012 – Headcounts  2012 – FTEs  2013 – Headcounts  2013 – FTEs
# 3        24161            33509.0        24848              33477        24903
# 4        19843              25805        20173              26118        20042

# %%
#Drop the first three rows on the df and reset the index
Student_df.drop(index=Student_df.index[:3], axis = 0, inplace = True)

#Check the first 5 rows of the df
Student_df.head()
# Out:
#   University 2009 – Headcounts 2009 - FTEs 2010 – Headcounts 2010 – FTEs  \
# 3       CPUT             30958       22690             32167       23854
# 4        UCT             23787       18854             24772       19652
# 5        CUT             12205        9697             12583        9863
# 6        DUT             24026       17335             25184       18903
# 7         FH             10016        8810             10741        9159
#
#   2011 – Headcounts 2011 – FTEs 2012 – Headcounts 2012 – FTEs  \
# 3             32506       24161           33509.0       24848
# 4             25301       19843             25805       20173
# 5             12644        9764           12724.0        9745
# 6             24840       18534             24875       18159
# 7             11144        9438             12044        9967
#
#   2013 – Headcounts 2013 – FTEs
# 3             33477       24903
# 4             26118       20042
# 5             13303        9963
# 6             26059       19237
# 7             12315       10305

# %%
#Reset the index
Student_df.reset_index(drop = True, inplace = True)

#Check the first 5 rows of the df
Student_df.head()
# Out:
#   University 2009 – Headcounts 2009 - FTEs 2010 – Headcounts 2010 – FTEs  \
# 0       CPUT             30958       22690             32167       23854
# 1        UCT             23787       18854             24772       19652
# 2        CUT             12205        9697             12583        9863
# 3        DUT             24026       17335             25184       18903
# 4         FH             10016        8810             10741        9159
#
#   2011 – Headcounts 2011 – FTEs 2012 – Headcounts 2012 – FTEs  \
# 0             32506       24161           33509.0       24848
# 1             25301       19843             25805       20173
# 2             12644        9764           12724.0        9745
# 3             24840       18534             24875       18159
# 4             11144        9438             12044        9967
#
#   2013 – Headcounts 2013 – FTEs
# 0             33477       24903
# 1             26118       20042
# 2             13303        9963
# 3             26059       19237
# 4             12315       10305

# %%
#Check the first 5 rows of the df
Student_df.tail()
# Out:
#    University 2009 – Headcounts 2009 - FTEs 2010 – Headcounts 2010 – FTEs  \
# 19        WSU             25356       21360             26734       22883
# 20        UWC             16203       12053             18059       14512
# 21       WITS             29234       21278             29498       21549
# 22         UZ             13291       11943             14725       13164
# 23      Total            837776      569706            892936      600002
#
#    2011 – Headcounts 2011 – FTEs 2012 – Headcounts 2012 – FTEs  \
# 19             27029       21615           24613.0       20347
# 20             18764       14874             19591       15367
# 21             29004       21228             30436       22644
# 22             15592       14206             16434       15583
# 23            938201      628410          953373.0      634549
#
#    2013 – Headcounts 2013 – FTEs
# 19             24122       19662
# 20             20383       15977
# 21             31134       23507
# 22             16591       13764
# 23            983698      665857

# %%
#Drop the last column
Student_df.drop(Student_df.index[-1:], inplace = True)

#Check the first 5 rows of the df
Student_df.tail()
# Out:
#    University 2009 – Headcounts 2009 - FTEs 2010 – Headcounts 2010 – FTEs  \
# 18     UNIVEN             11125        9893             10679        9091
# 19        WSU             25356       21360             26734       22883
# 20        UWC             16203       12053             18059       14512
# 21       WITS             29234       21278             29498       21549
# 22         UZ             13291       11943             14725       13164
#
#    2011 – Headcounts 2011 – FTEs 2012 – Headcounts 2012 – FTEs  \
# 18             10342        8399             10323        8122
# 19             27029       21615           24613.0       20347
# 20             18764       14874             19591       15367
# 21             29004       21228             30436       22644
# 22             15592       14206             16434       15583
#
#    2013 – Headcounts 2013 – FTEs
# 18             11818        9682
# 19             24122       19662
# 20             20383       15977
# 21             31134       23507
# 22             16591       13764

# %%
#Check the data types
Student_df.dtypes
# Out:
# University           object
# 2009 – Headcounts    object
# 2009 - FTEs          object
# 2010 – Headcounts    object
# 2010 – FTEs          object
# 2011 – Headcounts    object
# 2011 – FTEs          object
# 2012 – Headcounts    object
# 2012 – FTEs          object
# 2013 – Headcounts    object
# 2013 – FTEs          object
# dtype: object

# %%
#Convert all numeric columns to integer type
Student_df[Student_df.columns[1:]] = Student_df[Student_df.columns[1:]].astype(int)

#Check the data types
Student_df.dtypes
# Out:
# University           object
# 2009 – Headcounts     int64
# 2009 - FTEs           int64
# 2010 – Headcounts     int64
# 2010 – FTEs           int64
# 2011 – Headcounts     int64
# 2011 – FTEs           int64
# 2012 – Headcounts     int64
# 2012 – FTEs           int64
# 2013 – Headcounts     int64
# 2013 – FTEs           int64
# dtype: object

# %%
#Take a look at the summary stats of the dataset
Student_df.describe()
# Out:
#        2009 – Headcounts    2009 - FTEs  2010 – Headcounts    2010 – FTEs  \
# count          23.000000      23.000000          23.000000      23.000000
# mean        36425.043478   24769.782609       38823.304348   26087.000000
# std         51601.580295   26292.024328       57440.198135   28455.549797
# min          7012.000000    5881.000000        7169.000000    6026.000000
# 25%         14747.000000   11998.000000       16392.000000   13838.000000
# 50%         25356.000000   18854.000000       26119.000000   19652.000000
# 75%         34911.000000   25752.000000       36695.500000   27244.000000
# max        263559.000000  136108.000000      293437.000000  148275.000000
#
#        2011 – Headcounts    2011 – FTEs  2012 – Headcounts    2012 – FTEs  \
# count          23.000000      23.000000          23.000000      23.000000
# mean        40791.347826   27322.130435       41450.826087   27589.043478
# std         64537.571611   32501.629678       65978.454947   33170.658977
# min          7278.000000    6060.000000        7395.000000    6114.000000
# 25%         17178.000000   14540.000000       18012.500000   14937.000000
# 50%         26256.000000   19843.000000       25805.000000   20173.000000
# 75%         37134.000000   27709.000000       37686.000000   28278.000000
# max        328864.000000  168679.000000      336286.000000  172304.000000
#
#        2013 – Headcounts    2013 – FTEs
# count          23.000000      23.000000
# mean        42769.478261   28950.173913
# std         69790.339948   38123.033055
# min          7485.000000    6163.000000
# 25%         18487.000000   13754.000000
# 50%         26118.000000   19664.000000
# 75%         38739.500000   29099.500000
# max        355240.000000  197102.000000

# %%
#Check the info
Student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   University         23 non-null     object
#  1   2009 – Headcounts  23 non-null     int64
#  2   2009 - FTEs        23 non-null     int64
#  3   2010 – Headcounts  23 non-null     int64
#  4   2010 – FTEs        23 non-null     int64
#  5   2011 – Headcounts  23 non-null     int64
#  6   2011 – FTEs        23 non-null     int64
#  7   2012 – Headcounts  23 non-null     int64
#  8   2012 – FTEs        23 non-null     int64
#  9   2013 – Headcounts  23 non-null     int64
#  10  2013 – FTEs        23 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 2.2+ KB

# %%
#This row has a long University name; shorten it
Student_df.University.replace({"UL (Includes Sefako Makgoto Health Sciences University)": "UL+SMU"}, inplace=True)

# %%
for feature in Student_df.columns[1:]:
    sns.barplot(x = "University", y = feature, data = Student_df, order = Student_df.sort_values(feature, ascending=False).University)
    plt.title(feature)
    plt.xticks(rotation = 90)
    plt.show()
